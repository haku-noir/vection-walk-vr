# %%
import os 
os.getcwd()
# Out:
# 'D:\\UnityHub\\MyStudy\\Assets\\ResultData\\lookaround\\output_file'

# %%
import pandas as pd
file_name = "extracted_UDFB7_lookaround_results_20231116_171627.csv_1.csv"
df = pd.read_csv(file_name)
s = df["SplitTime"][2:51].mean()
print(s)
# Out:
# 0.835969885714286
